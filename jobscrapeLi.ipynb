# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %%
import time
import csv
import requests
import re
from bs4 import BeautifulSoup as bs

# %%
from selenium.webdriver import ActionChains
import numpy as np

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(PATH)

# %%
user = "mathis.brennan@gmail.com"
pw = "Shitballs1!"

# %%
def link_log(email, password):
    driver.get("https://www.linkedin.com/")
    driver.find_element_by_id("session_key").send_keys(email)
    driver.find_element_by_id("session_password").send_keys(password)
    driver.find_element_by_class_name("sign-in-form__submit-button").click()

# %%
link_log(user, pw)

# %%
# search_item variable to be used for search terms as string, even if multiple inputs, single string
def link_title_search(search_item):
    driver.find_element_by_id("global-nav-search").click()
    driver.find_element_by_xpath("//*[@id='ember20']/input").send_keys(search_item)
    driver.find_element_by_xpath("//*[@id='ember20']/input").send_keys(Keys.RETURN)
    
    print( "Search Criteria : " + search_item + " COMPLETE")

# %%
terms = 'data scientist'
link_title_search(terms)
# Out:
# Search Criteria : data scientist COMPLETE

# %%
driver.find_element_by_link_text("See all people results").click()

# %%
urls = []
names = []

# %%
pageSource = driver.page_source
time.sleep(2)
#pageSource =  driver.find_elements_by_css_selector("span.entity-result__title a.app-aware-link").get_attribute("")
lxml_soup = bs(pageSource, 'lxml')

# %%
job_container = lxml_soup.find('ul', class_ ="reusable-search__entity-results-list")
                               # searching for all job containers
search_container = lxml_soup.find('div', class_ = 'entity-result')

print('You are scraping information about {} connections.'.format(len(search_container)))
# Out:
# You are scraping information about 3 connections.

# %%
print(lxml_soup)
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(22) "data scientist" | Search | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/21m48fftxrxil7c8lck4bcp41" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="false" name="is-http2"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#0077B5" name="theme-color"/>
# ...

# %%
# searching for all job containers
search_container = lxml_soup.find('li', class_ = 'reusable-search__result-container')

print('You are scraping information about {} connections.'.format(len(search_container)))
# Out:
# You are scraping information about 3 connections.

# %%
currents=[]

# %%
currents
# Out:
# ['None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  '[]',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None']

# %%
links = driver.find_elements_by_css_selector("span.entity-result__title a.app-aware-link")
#urls = links.find_elements_by_css_selector("div.entity-result a.app-aware-link")
#"span.name.actor-name")
for link in links:
    print("======START ELEMENT====")
    print(link.get_attribute("innerText"))
    time.sleep(2)
    name = str(link.get_attribute("innerText")).split('\n')
    names.append(name[0])
    profile_path = (str(link.get_attribute("pathname")))
    urls.append(profile_path)
    cur = link.find_elements_by_class_name("entity-result__")
    time.sleep(2)
    current= str(cur.get_attribute('innerText'))
    currents.append(current)
    print("======END ELEMENT=====")
   # get other info parsing xml with bs? 
#connections = links.find_element_by_css_selector("a.app-aware-link")
#connection_name = connections.find_element_by_css_selector('').get_attribute('href')
#result = np.array([])
# Out:
# ======START ELEMENT====
# Michelle Lu
# View Michelle Lu’s profile
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-346-7190300ee76f> in <module>
#      12     cur = link.find_elements_by_class_name("entity-result__")
#      13     time.sleep(2)
# ---> 14     current= str(cur.get_attribute('innerText'))
#      15     currents.append(current)
#      16     print("======END ELEMENT=====")
#
# AttributeError: 'list' object has no attribute 'get_attribute'

# %%
urls
# Out:
# ['/in/lu-michellepy',
#  '/in/xiaoshuowang',
#  '/in/joseph-mchugh-b87349169',
#  '/in/jiawuphd',
#  '/in/pengyuwei',
#  '/in/sophia-scarano',
#  '/in/jalal-kiani-045721122',
#  '/in/msandreakoltai',
#  '/in/ederlyn-tanangco',
#  '/in/asher-lewis-5586b019a',
#  '/in/lu-michellepy',
#  '/in/xiaoshuowang',
#  '/in/joseph-mchugh-b87349169',
#  '/in/jiawuphd',
#  '/in/pengyuwei',
#  '/in/sophia-scarano',
#  '/in/jalal-kiani-045721122',
#  '/in/msandreakoltai',
#  '/in/ederlyn-tanangco',
#  '/in/asher-lewis-5586b019a',
#  '/in/lu-michellepy',
#  '/in/lu-michellepy',
#  '/in/lu-michellepy',
#  '/in/xiaoshuowang',
#  '/in/joseph-mchugh-b87349169',
#  '/in/jiawuphd',
#  '/in/pengyuwei',
#  '/in/sophia-scarano',
#  '/in/jalal-kiani-045721122',
#  '/in/msandreakoltai',
#  '/in/ederlyn-tanangco',
#  '/in/asher-lewis-5586b019a']

# %%
names
# Out:
# ['Michelle Lu',
#  'Summer Wang',
#  'Joseph McHugh',
#  'Jia Wu',
#  'Kelly(Yuwei) Peng',
#  'Sophia Scarano',
#  'Jalal Kiani',
#  'Andrea Koltai',
#  'Ederlyn Tanangco',
#  'Asher Lewis']

# %%
import pandas as pd

# %%
name_link_df = pd.DataFrame()
name_link_df['name'] = names
name_link_df['url'] = urls
name_link_df
# Out:
#                 name                          url
# 0        Michelle Lu            /in/lu-michellepy
# 1        Summer Wang             /in/xiaoshuowang
# 2      Joseph McHugh  /in/joseph-mchugh-b87349169
# 3             Jia Wu                 /in/jiawuphd
# 4  Kelly(Yuwei) Peng                /in/pengyuwei
# 5     Sophia Scarano           /in/sophia-scarano
# 6        Jalal Kiani    /in/jalal-kiani-045721122
# 7      Andrea Koltai           /in/msandreakoltai
# 8   Ederlyn Tanangco         /in/ederlyn-tanangco
# 9        Asher Lewis    /in/asher-lewis-5586b019a

# %%
driver.find_element_by_css_selector("#ember1883").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-298-90b0da7b155c> in <module>
# ----> 1 driver.find_element_by_css_selector("#ember1883").click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# ...

# %%
driver.quit()

# %%
html_text = requests.get(vgm_url).text
soup = BeautifulSoup(html_text, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-232-88f351ffca81> in <module>
# ----> 1 html_text = requests.get(vgm_url).text
#       2 soup = BeautifulSoup(html_text, 'html.parser')
#
# NameError: name 'vgm_url' is not defined

# %%
driver.forward()
driver.back()

# %%
driver.quit()

# %%
# defining new variable passing two parameters
writer = csv.writer(open(parameters.(f'{terms}.csv'), 'wb'))

# writerow() method to the write to the file object
writer.writerow(['Name', 'Job Title', 'Company', 'College', 'Location', 'URL'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-7d6546237e4d> in <module>
#       1 # defining new variable passing two parameters
# ----> 2 writer = csv.writer(open(parameters.file_name, 'wb'))
#       3
#       4 # writerow() method to the write to the file object
#       5 writer.writerow(['Name', 'Job Title', 'Company', 'College', 'Location', 'URL'])
#
# NameError: name 'parameters' is not defined

# %%
r = requests.get(‘https://api.scrapingdog.com/linkedin/?api_key=600344ed3a4c666ef1af053a&type=company&linkId=google/about/').text
# Out:
#   File "<ipython-input-50-654b909c6353>", line 1
#     r = requests.get(‘https://api.scrapingdog.com/linkedin/?api_key=600344ed3a4c666ef1af053a&type=company&linkId=google/about/').text
#                           ^
# SyntaxError: invalid character in identifier

# %%
driver.quit()
